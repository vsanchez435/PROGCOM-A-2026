# %% [markdown]
# <a href="https://colab.research.google.com/github/vsanchez435/PROGCOM-A-2026/blob/main/LISTAS_Y_DICCIONAROS_PARTE_3_13_marzo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Comida=["combo 1", "combo 2", "combo 3", "combo 4","papas", "jugos naturales","cerveza", "agua" "gaseosa"]
precios= [20000, 25000, 18000, 24500, 3000, 7000, 3500, 4000, 2500]

# %%
for menu in range(len(Comida)):
  print(Comida[menu], "-", precios[menu])
# Out:
# combo 1 - 20000
# combo 2 - 25000
# combo 3 - 18000
# combo 4 - 24500
# papas - 3000
# jugos naturales - 7000
# cerveza - 3500
# aguagaseosa - 4000

# %%
a=0
r="s"
user="s"
while user=="s":
  while r=="s":
    x=input( "Qué desea?")
    if x=="combo 1": a=a+20000
    elif x== "combo 2": a=a+25000
    elif x==" combo 3": a=a+18000
    elif x=="combo 4": a=a+24500
    elif x=="papas": a=a+3000
    elif x=="Jugos naturales": a=a+7000
    elif x=="cerveza": a=a+3500
    elif x=="agua": a=a+4000
    elif x=="gaseosas": a=a+2500
    else:
      x=input ("Desea algo más?")
      if x=="s": continue
      else: break
    user=input ("Hay más usuarios?")
  print(f"Usted ha ganado ${a} en el día")
# Out:
# Qué desea?combo 1
# Hay más usuarios?si

# %%
a=6
r="s"
user="s"
while user=="s":
  while r=="s":
    cantidad=input ("ingresa la cantidad del producto:")
    x=input( "Qué desea?")
    if x=="combo 1": a=a+20000*cantidad
    elif x== "combo 2": a=a+25000*cantidad
    elif x==" combo 3": a=a+18000*cantidad
    elif x=="combo 4": a=a+24500*cantidad
    elif x=="papas": a=a+3000*cantidad
    elif x=="Jugos naturales": a=a+7000*cantidad
    elif x=="cerveza": a=a+3500*cantidad
    elif x=="agua": a=a+4000*cantidad
    elif x=="gaseosas": a=a+2500*cantidad
    print(f"pediste {cantidad} de {x}")
    else:
      x=input ("Desea algo más?")
      if x=="s": continue
      else: break
    user=input ("Hay más usuarios?")
  print(f"Usted ha ganado ${a} en el día")
