# %% [markdown]
# <a href="https://colab.research.google.com/github/vsanchez435/PROGCOM-A-2026/blob/main/LISTAS_Y_DICCIONARIOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Quiero saber cuantos estudiantes sacan mas que que promedio
suma=0
estudiantes= int(input("Cuantos estudiantes son?"))
for i in range(estudiantes):
  notas=float(input("Ingrese las notas de cada uno:"))
  suma+=notas
promedio=suma/estudiantes
print(f"el promedio es:{promedio}")
for i in range(estudiantes):
  if notas>promedio:
    c=c+1
print(f"{c}estudiantes sacaron mayor nota que el promedio")
# Out:
# Cuantos estudiantes son?3
# Ingrese las notas de cada uno:1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_437/2518542158.py in <cell line: 0>()
#       3 estudiantes= int(input("Cuantos estudiantes son?"))
#       4 for i in range(estudiantes):
# ----> 5   notas=float(input("Ingrese las notas de cada uno:"))
#       6   suma+=notas
#       7 promedio=suma/estudiantes
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %% [markdown]
# #LISTAS
# Es una colección de elementos que complen las siguientes características
# 1. Mutables
# 2. tiene index
#
# Litas son: MUTABLES
# (Existen mutables e inmutables
#
# ###CREACIÓN DE LISTAS
# nombre_listas=[]
#
# Existen dos formas de crear una lista:
# 1. Por extensión: Se nombran uno a uno los elementos
# 2. Por comprensión: Se enuncian las características comunes de los elementos

# %%
galleta=["Ángeles","Dinosaurios", "Diablitos"]
cantidad=[2,2,3]

# %% [markdown]
# RECORRIENDO ELEMENTOS DE FORMA MANUAL
#
#
# ```
# nombre_lista[posición de interes]
# ```

# %%
galleta[2]
# Out:
# 'Diablitos'

# %%
cantidad[2]
# Out:
# 3

# %% [markdown]
# RECORRIENDO LAS LISTAS DE FORMA AUTOMÁTICA

# %%
for caja in range(3):
  print(f"{galleta[caja]}:{cantidad[caja]}")
# Out:
# Ángeles:2
# Dinosaurios:2
# Diablitos:3

# %%
5#Quiero saber cuantos estudiantes sacan mas que que promedio
suma=0
c=0
notas=[]
estudiantes= int(input("Cuantos estudiantes son?"))
for i in range(estudiantes):
  nota=float(input("Ingrese las notas de cada uno:"))
  notas.append(nota)
  suma=suma+nota
promedio=suma/estudiantes
print(f"el promedio es:{promedio}")
for i in range(estudiantes):
  if notas[i]>promedio:
    c=c+1
print(f"{c}estudiantes sacaron mayor nota que el promedio")
# Out:
# Cuantos estudiantes son?5
# Ingrese las notas de cada uno:5
# Ingrese las notas de cada uno:6
# Ingrese las notas de cada uno:9
# Ingrese las notas de cada uno:6
# Ingrese las notas de cada uno:8
# el promedio es:6.8
# 2estudiantes sacaron mayor nota que el promedio

# %%
n = int(input("Ingrese la cantidad de trabajadores: "))

trabajadores = []
sueldos = []

for i in range(n):
    nombre = input("Nombre del trabajador: ")
    sueldo = float(input("Sueldo: "))

    trabajadores.append(nombre)
    sueldos.append(sueldo)

promedio = sum(sueldos) / n

print("Promedio:", promedio)
print("Trabajadores que ganan más que el promedio:")

for i in range(n):
    if sueldos[i] > promedio:
        print(trabajadores[i])
# Out:
# Ingrese la cantidad de trabajadores: 4
# Nombre del trabajador: pepe
# Sueldo: 200
# Nombre del trabajador: Juan
# Sueldo: 600
# Nombre del trabajador: Cami
# Sueldo: 300
# Nombre del trabajador: Tomas
# Sueldo: 100
# Promedio: 300.0
# Trabajadores que ganan más que el promedio:
# Juan

# %%
n = int(input("¿Cuántos productos tendrá la tienda?: "))

productos = []
precios = []

for i in range(n):
    producto = input("Nombre del producto: ")
    precio = float(input("Precio: "))

    productos.append(producto)
    precios.append(precio)

print("\nMENÚ DE LA TIENDA")

for i in range(n):
    print(i+1, "-", productos[i], "$", precios[i])
# Out:
# ¿Cuántos productos tendrá la tienda?: 3
# Nombre del producto: Pan
# Precio: 2000
# Nombre del producto: Queso
# Precio: 6000
# Nombre del producto: leche
# Precio: 5000
#
# MENÚ DE LA TIENDA
# 1 - Pan $ 2000.0
# 2 - Queso $ 6000.0
# 3 - leche $ 5000.0

# %%
cantidad = int(input("Cantidad de números: "))

numeros = []

for i in range(cantidad):
    num = int(input("Ingrese número: "))
    numeros.append(num)

n = int(input("Ingrese el número para saber sus múltiplos: "))

contador = 0

for num in numeros:
    if num % n == 0:
        contador += 1

print("Cantidad de múltiplos:", contador)
# Out:
# Cantidad de números: 10
# Ingrese número: 1
# Ingrese número: 2
# Ingrese número: 3
# Ingrese número: 6
# Ingrese número: 5
# Ingrese número: 4
# Ingrese número: 9
# Ingrese número: 8
# Ingrese número: 7
# Ingrese número: 10
# Ingrese el número para saber sus múltiplos: 6
# Cantidad de múltiplos: 1

# %%
n = int(input("Cantidad de pacientes: "))

pacientes = []
fechas = []

for i in range(n):
    nombre = input("Nombre del paciente: ")
    vacuna = input("¿Está vacunado? (si/no): ")

    pacientes.append(nombre)

    if vacuna == "si":
        fecha = input("Fecha de vacunación: ")
        fechas.append(fecha)
    else:
        fechas.append("No vacunado")

contador = 0

print("\nPacientes vacunados:")

for i in range(n):
    if fechas[i] != "No vacunado":
        print(pacientes[i], "-", fechas[i])
        contador += 1

print("Total vacunados:", contador)
# Out:
# Cantidad de pacientes: 4
# Nombre del paciente: juan
# ¿Está vacunado? (si/no): si
# Fecha de vacunación: 30 sep  2025
# Nombre del paciente: Geraldine
# ¿Está vacunado? (si/no): no
# Nombre del paciente: pepe
# ¿Está vacunado? (si/no): no
# Nombre del paciente: caMILO
# ¿Está vacunado? (si/no): SI
#
# Pacientes vacunados:
# juan - 30 sep  2025
# Total vacunados: 1
